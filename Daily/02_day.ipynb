# %% [markdown]
# # Day 02
#
# ## What I did today
# - Revised Python
#     - Data structures
#     - functions
#     - OOps
#     - File handling
#     - Exception handling
# - Did all this through udemy course and solved exercise
#
# ## What I learned
# - Made Phonebook using functions
#
# ## Code is added in my Begineer_projects repo
#
# ## Problems I faced
# - structure of code
